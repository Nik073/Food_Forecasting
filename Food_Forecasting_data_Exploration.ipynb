# %%
cd Desktop
# Out:
# /Users/chanpreetsingh/Desktop

# %%
ls
# Out:
# ARIMA/
# Desktop/
# EMBdd_p2/
# S1A_IW_GRDH_1SDV_20191004T011831_20191004T011856_029302_035471_E23D.SAFE/
# TensorRT1/
# current/
# e_/
# embdd LAB/
# internship_01/

# %%
cd current
# Out:
# /Users/chanpreetsingh/Desktop/current

# %%
ls
# Out:
# AMD/                 Resume-template.doc  food_prediction/
# Deep_Fake/           Resume.pdf

# %%
cd food_prediction
# Out:
# /Users/chanpreetsingh/Desktop/current/food_prediction

# %%
ls
# Out:
# fulfilment_center_info.csv  test.csv
# meal_info.csv               train.csv
# model1_sample.ipynb         train3C.csv
# submission.csv

# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('train.csv')

# %%
train.isnull().sum()
# Out:
# id                       0
# week                     0
# center_id                0
# meal_id                  0
# checkout_price           0
# base_price               0
# emailer_for_promotion    0
# homepage_featured        0
# num_orders               0
# city_code                0
# region_code              0
# center_type              0
# op_area                  0
# category                 0
# cuisine                  0
# dtype: int64

# %%
test=pd.read_csv('test.csv')

# %%
test.shape
# Out:
# (32573, 8)

# %%
center=pd.read_csv('fulfilment_center_info.csv')

# %%
center.shape
# Out:
# (77, 5)

# %%
meal=pd.read_csv('meal_info.csv')

# %%
meal.shape
# Out:
# (51, 3)

# %%
meal.head()
# Out:
#    meal_id   category cuisine
# 0     1885  Beverages    Thai
# 1     1993  Beverages    Thai
# 2     2539  Beverages    Thai
# 3     1248  Beverages  Indian
# 4     2631  Beverages  Indian

# %%
center.head()
# Out:
#    center_id  city_code  region_code center_type  op_area
# 0         11        679           56      TYPE_A      3.7
# 1         13        590           56      TYPE_B      6.7
# 2        124        590           56      TYPE_C      4.0
# 3         66        648           34      TYPE_A      4.1
# 4         94        632           34      TYPE_C      3.6

# %%
train.head()
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1379560     1         55     1885          136.83      152.29
# 1  1466964     1         55     1993          136.83      135.83
# 2  1346989     1         55     2539          134.86      135.86
# 3  1338232     1         55     2139          339.50      437.53
# 4  1448490     1         55     2631          243.50      242.50
#
#    emailer_for_promotion  homepage_featured  num_orders  city_code  \
# 0                      0                  0         177      647.0
# 1                      0                  0         270      647.0
# 2                      0                  0         189      647.0
# 3                      0                  0          54      647.0
# 4                      0                  0          40      647.0
#
#    region_code center_type  op_area   category cuisine
# 0         56.0      TYPE_C      2.0  Beverages    Thai
# 1         56.0      TYPE_C      2.0  Beverages    Thai
# ...

# %%
submission= pd.read_csv('submission.csv')

# %%
submission.head()
# Out:
#         id  num_orders
# 0  1028232           0
# 1  1127204           0
# 2  1212707           0
# 3  1082698           0
# 4  1400926           0

# %%
index1=-1
index2=-1
for i in train['center_id'] :
    
    index2=index2+1
    for j in center['center_id']:
        
        index1=index1+1
        if (i==j):
            train.loc[train.index[index2], 'city_code'] = center.iloc[index1].values[1]
            train.loc[train.index[index2], 'region_code'] = center.iloc[index1].values[2]
            train.loc[train.index[index2], 'center_type'] = center.iloc[index1].values[3]
            train.loc[train.index[index2], 'op_area'] = center.iloc[index1].values[4]
            
        
            
            
            
           
            
         
            
    index1=-1  
    
    if(index2%100==0):
        print(index2)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
train
# Out:
#              id  week  center_id  meal_id  checkout_price  base_price  \
# 0       1379560     1         55     1885          136.83      152.29
# 1       1466964     1         55     1993          136.83      135.83
# 2       1346989     1         55     2539          134.86      135.86
# 3       1338232     1         55     2139          339.50      437.53
# 4       1448490     1         55     2631          243.50      242.50
# ...         ...   ...        ...      ...             ...         ...
# 456543  1271326   145         61     1543          484.09      484.09
# 456544  1062036   145         61     2304          482.09      482.09
# 456545  1110849   145         61     2664          237.68      321.07
# 456546  1147725   145         61     2569          243.50      313.34
# 456547  1361984   145         61     2490          292.03      290.03
#
#         emailer_for_promotion  homepage_featured  num_orders  city_code  \
# ...
